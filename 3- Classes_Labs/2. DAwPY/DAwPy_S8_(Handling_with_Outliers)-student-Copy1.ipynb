# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/6gCsHd6/1200px-Pandas-logo-svg.png width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Session - 08</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:200%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#0)
# * [HANDLING WITH OUTLIERS](#1)
# * [CATCHING & DETECTING OUTLIERS](#2)
# * [REMOVING THE OUTLIERS](#3)
# * [LIMITATION & TRANSFORMATION OF THE OUTLIERS](#4)
# * [THE END OF THE SESSION - 07](#5)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Libraries Needed in This Notebook</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### What is Outlier? [Source](https://statisticsbyjim.com/basics/remove-outliers/#:~:text=Outliers%20are%20unusual%20values%20in,what%20to%20do%20with%20them.)
#
# In general, <b>``Outliers``</b> are **unusual values** in your dataset, and they can **distort statistical analyses and violate their assumptions**. ... Outliers increase the variability in your data, which decreases statistical power. Consequently, excluding outliers can cause your results to become statistically significant. Outliers can have a disproportionate effect on statistical results, such as the mean, which can result in misleading interpretations. In this case, the mean value makes it seem that the data values are higher than they really are.

# %% [markdown]
# ### Most common causes of outliers on a data set [Source](https://towardsdatascience.com/a-brief-overview-of-outlier-detection-techniques-1e0b2c19e561):
#
# - Data entry errors (human errors)
# - Measurement errors (instrument errors)
# - Experimental errors (data extraction or experiment planning/executing errors)
# - Intentional (dummy outliers made to test detection methods)
# - Data processing errors (data manipulation or data set unintended mutations)
# - Sampling errors (extracting or mixing data from wrong or various sources)
# - Natural (not an error, novelties in data)

# %% [markdown]
# ### Guideline for Handling Outliers [Source 01](https://statisticsbyjim.com/basics/remove-outliers/#:~:text=Outliers%20are%20unusual%20values%20in,what%20to%20do%20with%20them.) & [Source 02](https://www.researchgate.net/publication/258174106_Best-Practice_Recommendations_for_Defining_Identifying_and_Handling_Outliers)
#
# - A measurement error or data entry error, correct the error if possible. If you can’t fix it, remove that observation because you know it’s incorrect.
# - Not a part of the population you are studying (i.e., unusual properties or conditions), you can legitimately remove the outlier.
# - A natural part of the population you are studying, you should not remove it.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Catching and Detecting Outliers</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("diamonds")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.info()  #satir ve sütun sayisi, null var mi data tipi ne bunlari verir. ###missing value yokmus , 53940 rows var ve ayni rakami gördük
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.duplicated().sum()
# Out:
# 146

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# **info about dataset**
# - **carat   :**Carat weight of the diamond
# - **depth % :**The height of a diamond, measured from the culet to the table, divided by its average girdle diameter
# - **table % :**The width of the diamond's table expressed as a percentage of its average diameter
# - **price   :**the price of the diamond
# - **x       :**length mm
# - **y       :**width mm
# - **z       :**higth mm

# %% [markdown]
# ### Detecting Outliers with Graphs

# %%
plt.figure(figsize =(15, 8))
sns.boxplot(x = df["table"])
# Out:
# <AxesSubplot:xlabel='table'>

# %%
plt.figure(figsize =(15, 8))
sns.displot(x = df["table"], bins =10)  #bins datayi araliklara bölüyor

# %%
df.table.sort_values()
# Out:
# 11368    43.0
# 35633    44.0
# 5979     49.0
# 22701    49.0
# 25179    50.0
#          ...
# 52861    73.0
# 52860    73.0
# 51342    76.0
# 50773    79.0
# 24932    95.0
# Name: table, Length: 53940, dtype: float64

# %%
df.table.sort_values(ascending= True)
# Out:
# 11368    43.0
# 35633    44.0
# 5979     49.0
# 22701    49.0
# 25179    50.0
#          ...
# 52861    73.0
# 52860    73.0
# 51342    76.0
# 50773    79.0
# 24932    95.0
# Name: table, Length: 53940, dtype: float64

# %%
df.table.sort_values(ascending= True).tail(10)    #en yüksek 10 degeri gördük
# Out:
# 23067    70.0
# 43705    70.0
# 44938    71.0
# 51391    73.0
# 49375    73.0
# 52861    73.0
# 52860    73.0
# 51342    76.0
# 50773    79.0
# 24932    95.0
# Name: table, dtype: float64

# %%
df.table.sort_values(ascending= True).tail(10).index
# Out:
# Int64Index([23067, 43705, 44938, 51391, 49375, 52861, 52860, 51342, 50773,
#             24932],
#            dtype='int64')

# %%
tail_index = df.table.sort_values(ascending= True).tail(10)
tail_index
# Out:
# 23067    70.0
# 43705    70.0
# 44938    71.0
# 51391    73.0
# 49375    73.0
# 52861    73.0
# 52860    73.0
# 51342    76.0
# 50773    79.0
# 24932    95.0
# Name: table, dtype: float64

# %%
df.loc[tail_index]
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 70   0.24  Very Good     D    VVS1   61.5   60.0    553  3.97  4.00  2.45
# 70   0.24  Very Good     D    VVS1   61.5   60.0    553  3.97  4.00  2.45
# 71   0.30  Very Good     H     SI1   63.1   56.0    554  4.29  4.27  2.70
# 73   0.30    Premium     H     SI1   62.5   57.0    554  4.29  4.25  2.67
# 73   0.30    Premium     H     SI1   62.5   57.0    554  4.29  4.25  2.67
# 73   0.30    Premium     H     SI1   62.5   57.0    554  4.29  4.25  2.67
# 73   0.30    Premium     H     SI1   62.5   57.0    554  4.29  4.25  2.67
# 76   0.26  Very Good     E    VVS2   59.9   58.0    554  4.15  4.23  2.51
# 79   0.26  Very Good     E    VVS1   62.6   59.0    554  4.06  4.09  2.55
# 95   0.70       Good     E     VS2   57.5   58.0   2759  5.85  5.90  3.38

# %% [markdown]
# ### Detecting Outliers with Tukey's Fences | Tukey's Rule

# %% [markdown]
# **- First way** of specifying **``Q1 & Q3``** is using the **``.quantile()``** method

# %%
Q1 =df["table"].quantile(0.25)
Q3 =df["table"].quantile(0.75)
IQR = Q3-Q1
IQR
# Out:
# 3.0

# %%
Q1
# Out:
# 56.0

# %%
Q3
# Out:
# 59.0

# %% [markdown]
# **- Second way** of specifying **``Q1 & Q3``** is using the **``.describe()``** method

# %%
df.table.describe()
# Out:
# count    53940.000000
# mean        57.457184
# std          2.234491
# min         43.000000
# 25%         56.000000
# 50%         57.000000
# 75%         59.000000
# max         95.000000
# Name: table, dtype: float64

# %%
Q1 =df.table.describe().loc["25%"]   #2. yöntem
Q3 =df.table.describe().loc["75%"]
IQR = Q3-Q1
IQR
# Out:
# 3.0

# %%
from scipy import stats ###3. metod

# %%
IQR =stats.iqr(df["table"])
IQR
# Out:
# 3.0

# %%
df.table.min()
# Out:
# 43.0

# %%
lower_limit =Q1 - 1.5 * IQR
upper_limit =Q3 + 1.5 * IQR

# %%
lower_limit
# Out:
# 51.5

# %%
df.table.max()
# Out:
# 95.0

# %%
upper_limit
# Out:
# 63.5

# %%
df[df.table < lower_limit]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 1515    0.91       Fair     F     SI2   65.3   51.0   2996  6.05  5.98  3.93
# 3238    0.94       Fair     H     SI2   66.0   50.1   3353  6.13  6.17  4.06
# 3979    1.00    Premium     H     SI1   62.2   51.0   3511  6.47  6.40  4.00
# 4150    0.91    Premium     F     SI2   61.0   51.0   3546  6.24  6.21  3.80
# 5979    1.00       Fair     I     VS1   64.0   49.0   3951  6.43  6.39  4.10
# 7418    1.02       Fair     F     SI1   61.8   50.0   4227  6.59  6.51  4.05
# 8853    1.00       Fair     E     VS2   66.4   51.0   4480  6.31  6.22  4.16
# 11368   1.04      Ideal     I     VS1   62.9   43.0   4997  6.45  6.41  4.04
# 22701   0.30       Fair     E     SI1   64.5   49.0    630  4.28  4.25  2.75
# 25179   2.00       Fair     H     SI1   61.2   50.0  13764  8.17  8.08  4.97
# 26387   2.01       Good     H     SI2   64.0   51.0  15888  8.08  8.01  5.15
# ...

# %%
(df.table < lower_limit).sum()
# Out:
# 16

# %%
(df.table > upper_limit).sum()
# Out:
# 589

# %%
df.table[(df.table < lower_limit)  | (df.table > upper_limit)]
# Out:
# 2        65.0
# 91       69.0
# 145      64.0
# 219      64.0
# 227      67.0
#          ...
# 53695    65.0
# 53697    65.0
# 53756    64.0
# 53757    64.0
# 53785    65.0
# Name: table, Length: 605, dtype: float64

# %%
df.table[(df.table < lower_limit)   | (df.table > upper_limit)].count()
# Out:
# 605

# %%
df.table[~(df.table < lower_limit)   | (df.table > upper_limit)].count()
# Out:
# 53924

# %%
df.table[(df.table >= lower_limit)   &  (df.table <= upper_limit)].count()
# Out:
# 53335

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Removing the Outliers</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
not_outliers = (df.table >= lower_limit) & (df.table <= upper_limit) ###burda tüm datalar geliyor, true lar cikinca 53335
not_outliers
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 53935     True
# 53936     True
# 53937     True
# 53938     True
# 53939     True
# Name: table, Length: 53940, dtype: bool

# %%
df[not_outliers]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53335 rows x 10 columns]

# %%
cleaned_df = df[not_outliers]    
cleaned_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53335 rows x 10 columns]

# %%
outlier_index = df.loc[(df.table < lower_limit ) | (df.table > upper_limit)].index
outlier_index
# Out:
# Int64Index([    2,    91,   145,   219,   227,   239,   296,   314,   356,
#               359,
#             ...
#             53226, 53503, 53542, 53577, 53660, 53695, 53697, 53756, 53757,
#             53785],
#            dtype='int64', length=605)

# %%
df.drop(outlier_index)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53335 rows x 10 columns]

# %%
(df.table < lower_limit)   |  (df.table > upper_limit)
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Name: table, Length: 53940, dtype: bool

# %%
(df.table >= lower_limit)   &  (df.table <= upper_limit)
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 53935     True
# 53936     True
# 53937     True
# 53938     True
# 53939     True
# Name: table, Length: 53940, dtype: bool

# %%
df[not_outliers]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53335 rows x 10 columns]

# %%
not_outliers = (df.table >= lower_limit)   & (df.table <= upper_limit)
not_outliers
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 53935     True
# 53936     True
# 53937     True
# 53938     True
# 53939     True
# Name: table, Length: 53940, dtype: bool

# %%
df.loc[df.table[(df.table < lower_limit)   | (df.table > upper_limit)].count()]
# Out:
# carat           0.74
# cut        Very Good
# color              E
# clarity          SI1
# depth           60.0
# table           57.0
# price           2839
# x               5.85
# y               5.89
# z               3.52
# Name: 605, dtype: object

# %%
pd.DataFrame([df.table.describe(), cleaned_df.table.describe()], index=['before', 'after']).T
# Out:
#              before         after
# count  53940.000000  53335.000000
# mean      57.457184     57.373404
# std        2.234491      2.074349
# min       43.000000     51.600000
# 25%       56.000000     56.000000
# 50%       57.000000     57.000000
# 75%       59.000000     59.000000
# max       95.000000     63.500000

# %%
plt.figure(figsize = (15,8))  #artik outliers yok burda
sns.boxplot(x = cleaned_df.table);

# %%
plt.figure(figsize = (15,8))
sns.displot(x = cleaned_df.table, bins = 10);

# %%
df.table.describe()
# Out:
# count    53940.000000
# mean        57.457184
# std          2.234491
# min         43.000000
# 25%         56.000000
# 50%         57.000000
# 75%         59.000000
# max         95.000000
# Name: table, dtype: float64

# %%
cleaned_df.table.describe()
# Out:
# count    53335.000000
# mean        57.373404
# std          2.074349
# min         51.600000
# 25%         56.000000
# 50%         57.000000
# 75%         59.000000
# max         63.500000
# Name: table, dtype: float64

# %%
pd.DataFrame([df.table.describe(), cleaned_df.table.describe()], index = ["before", "after"]).T
# Out:
#              before         after
# count  53940.000000  53335.000000
# mean      57.457184     57.373404
# std        2.234491      2.074349
# min       43.000000     51.600000
# 25%       56.000000     56.000000
# 50%       57.000000     57.000000
# 75%       59.000000     59.000000
# max       95.000000     63.500000

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Limitation & Transformation of the Outliers</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ## Limitation using ``.winsorize()`` method
#
# With winsorizing, any value of a variable above or below a percentile k on each side of the variables’ distribution is replaced with the value of the k-th percentile itself. For example, if k=5, all observations above the 95th percentile are recoded to the value of the 95th percentile, and values below the 5th percent are recoded, respectively [Source 01](https://towardsdatascience.com/detecting-and-treating-outliers-in-python-part-3-dcb54abaf7b0) & [Source 02](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mstats.winsorize.html).

# %% [markdown]
# Cautions on Winsorizing Data
# Here are a few things to keep in mind when deciding to winsorize data:
#
# 1. If there aren’t extreme outliers, then winsorizing the data will only modify the smallest and largest values slightly. This is generally not a good idea since it means we’re just modifying data values for the sake of modifications.
#
# 2. Outliers can represent interesting edge cases in the data. Thus, before modifying outliers it’s a good idea to take a closer look at them to see what could have caused them.
#
# 3. You should decide whether or not to winsorize data after collecting the data, not before. You should see if there actually are extreme outliers before you decide to perform winsorization. If no extreme outliers are present, winsorization may be unnecessary.

# %%
from scipy.stats.mstats import winsorize

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
winsorize(df.table, (0.02, 0.05))  #lower ve upper limit
# Out:
# masked_array(data=[55., 61., 61., ..., 60., 58., 55.],
#              mask=False,
#        fill_value=1e+20)

# %%
df.table[df.table < lower_limit]
# Out:
# 1515     51.0
# 3238     50.1
# 3979     51.0
# 4150     51.0
# 5979     49.0
# 7418     50.0
# 8853     51.0
# 11368    43.0
# 22701    49.0
# 25179    50.0
# 26387    51.0
# 33586    51.0
# 35633    44.0
# 45798    51.0
# 46040    51.0
# 47630    51.0
# Name: table, dtype: float64

# %%
a = len(df.table[df.table < lower_limit]) / len(df)   #16 yi toplama böldü.  oran hesapladik 16 yi toplama böldük
a
# Out:
# 0.00029662588060808305

# %%
b = len(df.table[df.table > upper_limit]) / len(df)
b
# Out:
# 0.010919540229885057

# %%
table_win = winsorize(df.table, (a, b))
table_win
# Out:
# masked_array(data=[55. , 61. , 63.5, ..., 60. , 58. , 55. ],
#              mask=False,
#        fill_value=1e+20)

# %%
len(table_win)
# Out:
# 53940

# %%
plt.figure(figsize =(15, 8))
sns.boxplot(x = table_win);

# %%
plt.figure(figsize =(15, 8))
sns.displot(x = table_win, bins = 10);

# %%
plt.figure(figsize =(15, 8))
sns.displot(x = table_win, bins = 50, kde = True);

# %%
plt.figure(figsize =(15, 8))
sns.displot(x = table_win, bins = 50, kde = True);

# %%
table_win   #array veriyor
# Out:
# masked_array(data=[55. , 61. , 63.5, ..., 60. , 58. , 55. ],
#              mask=False,
#        fill_value=1e+20)

# %%
table_win_ser = pd.Series(table_win)
table_win_ser
# Out:
# 0        55.0
# 1        61.0
# 2        63.5
# 3        58.0
# 4        58.0
#          ...
# 53935    57.0
# 53936    55.0
# 53937    60.0
# 53938    58.0
# 53939    55.0
# Length: 53940, dtype: float64

# %%
pd.DataFrame([df.table.describe(), cleaned_df.table.describe()], index = ["before", "after"]).T
# Out:
#              before         after
# count  53940.000000  53335.000000
# mean      57.457184     57.373404
# std        2.234491      2.074349
# min       43.000000     51.600000
# 25%       56.000000     56.000000
# 50%       57.000000     57.000000
# 75%       59.000000     59.000000
# max       95.000000     63.500000

# %%
pd.DataFrame([df.table.describe(), table_win_ser.describe()], index = ["before", "after"]).T       #min  ve max degerleri degisti
# Out:
# c:\Users\Birgül\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:4650: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
#              before         after
# count  53940.000000  53940.000000
# mean      57.457184     57.438591
# std        2.234491      2.161059
# min       43.000000     51.600000
# 25%       56.000000     56.000000
# 50%       57.000000     57.000000
# 75%       59.000000     59.000000
# max       95.000000     63.500000

# %%
pd.DataFrame([df.table.describe(), table_win_ser.describe(), cleaned_df.table.describe()], index=['original','winsorize', 'drop' ]).T
# Out:
# c:\Users\Birgül\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:4650: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
#            original     winsorize          drop
# count  53940.000000  53940.000000  53335.000000
# mean      57.457184     57.438591     57.373404
# std        2.234491      2.161059      2.074349
# min       43.000000     51.600000     51.600000
# 25%       56.000000     56.000000     56.000000
# 50%       57.000000     57.000000     57.000000
# 75%       59.000000     59.000000     59.000000
# max       95.000000     63.500000     63.500000

# %%
table_win_ser[table_win_ser == 51.6].count()
# Out:
# 17

# %%
table_win_ser[table_win_ser == 63.5].count()
# Out:
# 590

# %% [markdown]
# ## Transformation using ``log()`` method
#
# The **``Numpy.log()``** method lets you calculate the mathematical log of any number or array. The numpy.log() is a mathematical function that helps user to calculate Natural logarithm of x where x belongs to all the input array elements.
#
# The natural logarithm log is the inverse of the exponential function, so that log(exp(x)) = x. The natural logarithm is logarithm in base e [Source 01](https://www.geeksforgeeks.org/numpy-log-python/#:~:text=The%20numpy.,is%20log%20in%20base%20e.) & [Source 02](https://numpy.org/doc/stable/reference/generated/numpy.log.html).

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(x=df.carat);

# %%
plt.figure(figsize = (15, 8))
sns.displot(df.carat, bins=10, kde=False);

# %%
np.log(df.carat)
# Out:
# 0       -1.469676
# 1       -1.560648
# 2       -1.469676
# 3       -1.237874
# 4       -1.171183
#            ...
# 53935   -0.328504
# 53936   -0.328504
# 53937   -0.356675
# 53938   -0.150823
# 53939   -0.287682
# Name: carat, Length: 53940, dtype: float64

# %%
np.log10(df.carat)     #daha objektif sonuc verir
# Out:
# 0       -0.638272
# 1       -0.677781
# 2       -0.638272
# 3       -0.537602
# 4       -0.508638
#            ...
# 53935   -0.142668
# 53936   -0.142668
# 53937   -0.154902
# 53938   -0.065502
# 53939   -0.124939
# Name: carat, Length: 53940, dtype: float64

# %%
plt.figure(figsize = (15, 8))   #log uygulandiginda sagdaki 2 deger kalmis
sns.boxplot(x = np.log(df.carat));

# %%
plt.figure(figsize = (15, 8))
sns.displot(np.log(df.carat),  bins=10, kde=False);

# %%
df["carat_log"] = np.log(df.carat)
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %% [markdown]
# ## Removing outliers after log() transformation

# %% [markdown]
# **first method to drop outliers**

# %%
df.carat_log
# Out:
# 0       -1.469676
# 1       -1.560648
# 2       -1.469676
# 3       -1.237874
# 4       -1.171183
#            ...
# 53935   -0.328504
# 53936   -0.328504
# 53937   -0.356675
# 53938   -0.150823
# 53939   -0.287682
# Name: carat_log, Length: 53940, dtype: float64

# %%
df.carat_log.sort_values()   #azdan coga dogru gelir default olarak
# Out:
# 31593   -1.609438
# 31597   -1.609438
# 31596   -1.609438
# 31595   -1.609438
# 31594   -1.609438
#            ...
# 25999    1.388791
# 25998    1.388791
# 27130    1.418277
# 27630    1.504077
# 27415    1.611436
# Name: carat_log, Length: 53940, dtype: float64

# %%
df.carat_log.sort_values().nsmallest(2)
# Out:
# 31593   -1.609438
# 31597   -1.609438
# Name: carat_log, dtype: float64

# %%
df.carat_log.sort_values().nlargest(2)   #tail 2 ayni zamanda, nsmallest olsaydi head alacaktik
# Out:
# 27415    1.611436
# 27630    1.504077
# Name: carat_log, dtype: float64

# %%
df.carat_log.sort_values().tail(2)
# Out:
# 27630    1.504077
# 27415    1.611436
# Name: carat_log, dtype: float64

# %%
drop_index = df.carat_log.sort_values().nlargest(2).index
drop_index
# Out:
# Int64Index([27415, 27630], dtype='int64')

# %%
df.drop(drop_index)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %%
df.drop(index = [27415,27630])
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %% [markdown]
# **second method to drop outliers**

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %%
Q1 = df.carat_log.quantile(0.25)
Q1
# Out:
# -0.916290731874155

# %%
Q3 = df.carat_log.quantile(0.75)
Q3
# Out:
# 0.03922071315328133

# %%
IQR = Q3 - Q1
IQR
# Out:
# 0.9555114450274363

# %%
lower_limit = Q1 - 1.5 * IQR
lower_limit
# Out:
# -2.3495578994153097

# %%
upper_limit = Q3 + 1.5 * IQR
upper_limit
# Out:
# 1.472487880694436

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

lower_lim, upper_lim
# Out:
# (-2.3495578994153097, 1.472487880694436)

# %%
df[df.carat_log > upper_limit]
# Out:
#        carat   cut color clarity  depth  table  price      x      y     z  \
# 27415   5.01  Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50  Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
#
#        carat_log
# 27415   1.611436
# 27630   1.504077

# %%
df.carat_log < lower_limit
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Name: carat_log, Length: 53940, dtype: bool

# %%
(df.carat_log > upper_limit).sum()
# Out:
# 2

# %%
(df.carat_log <= lower_limit).sum()
# Out:
# 0

# %%
df[df.carat_log > upper_limit]    #loc ile ayni sonucu veriyor
# Out:
#        carat   cut color clarity  depth  table  price      x      y     z  \
# 27415   5.01  Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50  Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
#
#        carat_log
# 27415   1.611436
# 27630   1.504077

# %%
df.loc[(df.carat_log > upper_limit)]
# Out:
#        carat   cut color clarity  depth  table  price      x      y     z  \
# 27415   5.01  Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50  Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
#
#        carat_log
# 27415   1.611436
# 27630   1.504077

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %% [markdown]
# **third method to drop outliers**

# %%
not_outliers = (df.carat_log <= upper_limit)
not_outliers
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 53935    True
# 53936    True
# 53937    True
# 53938    True
# 53939    True
# Name: carat_log, Length: 53940, dtype: bool

# %%
df[not_outliers]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %%
df.loc[df.carat_log > upper_limit]
# Out:
#        carat   cut color clarity  depth  table  price      x      y     z  \
# 27415   5.01  Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50  Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
#
#        carat_log
# 27415   1.611436
# 27630   1.504077

# %%
(df.carat_log > upper_limit).sum()
# Out:
# 2

# %%
(df.carat_log < lower_limit).sum()
# Out:
# 0

# %%
df.loc[(df.carat_log > upper_lim)].index
# Out:
# Int64Index([27415, 27630], dtype='int64')

# %%
df.drop(index=[27415, 27630])
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %%
not_outliers = (df.carat_log <= upper_lim)
not_outliers
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 53935    True
# 53936    True
# 53937    True
# 53938    True
# 53939    True
# Name: carat_log, Length: 53940, dtype: bool

# %%
df[not_outliers]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %%
len(df[not_outliers])
# Out:
# 53938

# %%
cleaned_df = df[not_outliers]
cleaned_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %%
cleaned_df = df[not_outliers]
cleaned_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %%
plt.figure(figsize = (15, 8))
sns.boxplot(x = np.log(df.carat));

# %%
plt.figure(figsize = (15, 8))
sns.boxplot(x = cleaned_df.carat_log);

# %%
cleaned_df.drop("carat", axis =1)
# Out:
#              cut color clarity  depth  table  price     x     y     z  \
# 0          Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1        Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2           Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3        Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4           Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...          ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# 1      -1.560648
# 2      -1.469676
# 3      -1.237874
# 4      -1.171183
# ...

# %%
cleaned_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %%
cleaned_df.drop("carat", axis =1, inplace = True)
# Out:
# C:\Users\Birgül\AppData\Local\Temp\ipykernel_24484\1011186463.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.drop("carat", axis =1, inplace = True)

# %%
cleaned_df
# Out:
#              cut color clarity  depth  table  price     x     y     z  \
# 0          Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1        Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2           Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3        Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4           Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...          ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# 1      -1.560648
# 2      -1.469676
# 3      -1.237874
# 4      -1.171183
# ...

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        carat_log
# 0      -1.469676
# ...

# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of The Session - 08</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ____
